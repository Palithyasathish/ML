# %%
# required libraries
import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from matplotlib import image

# %%
df = pd.read_csv("yash_image_data_ml.csv")

# %%
df
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# 1      0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# 2      0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# 3      0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# 4      0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# ...         ...       ...       ...       ...       ...       ...       ...
# 41995  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 41996  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 41997  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 41998  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 41999  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42000 entries, 0 to 41999
# Columns: 785 entries, 0 to index
# dtypes: float64(784), int64(1)
# memory usage: 251.5 MB

# %%
df.isna().sum()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 780      0
# 781      0
# 782      0
# 783      0
# index    0
# Length: 785, dtype: int64

# %%
X = df.iloc[:,0:784]
y = df["index"]

# %%
X
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# 1      0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# 2      0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# 3      0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# 4      0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# ...         ...       ...       ...       ...       ...       ...       ...
# 41995  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 41996  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 41997  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 41998  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 41999  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
#
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41995    9
# 41996    9
# 41997    9
# 41998    9
# 41999    9
# Name: index, Length: 42000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.75, random_state = 100)

# %%
X_train
# Out:
#               0         1         2         3         4         5         6  \
# 33145  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 25613  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 21792  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 32368  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 3667   0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# ...         ...       ...       ...       ...       ...       ...       ...
# 16304  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 79     0.329412  0.329412  0.329412  0.329412  0.329412  0.329412  0.329412
# 12119  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 14147  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 38408  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
#
# ...

# %%
X_test
# Out:
#               0         1         2         3         4         5         6  \
# 21028  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 35662  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 7969   0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 16537  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 36659  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# ...         ...       ...       ...       ...       ...       ...       ...
# 6455   0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 24650  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 41717  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 19934  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
# 4953   0.266667  0.266667  0.266667  0.266667  0.266667  0.266667  0.266667
#
# ...

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
lr_classifier = LogisticRegression()
lr_classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
LR_y_test_pred =lr_classifier.predict(X_test)

# %%
LR_y_test_pred
# Out:
# array([4, 8, 1, ..., 4, 4, 6], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, LR_y_test_pred))
# Out:
# 0.9006666666666666

# %%
LR_y_test_pred.shape
# Out:
# (10500,)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
DT_y_test_pred =dt_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, DT_y_test_pred))
# Out:
# 0.8032380952380952

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
RF_y_test_pred =rf_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, DT_y_test_pred))
# Out:
# 0.8032380952380952

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
KNN_y_test_pred =knn_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, KNN_y_test_pred))
# Out:
# 0.8833333333333333

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
sv_classifier = SVC()
sv_classifier.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_test_pred = sv_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred))
# Out:
# 0.9572380952380952

# %%
data = pd.DataFrame([["LogisticRegression",0.9006666666666666],["Decision Tree",0.7998095238095239],["Random Forest",0.7998095238095239],["K-Nearest Neighbors",0.8833333333333333],["support vector classifier",0.9572380952380952]])
data.columns=["Train_Classification","Train_Accuracy"]

# %%
data
# Out:
#         Train_Classification  Train_Accuracy
# 0         LogisticRegression        0.900667
# 1              Decision Tree        0.799810
# 2              Random Forest        0.799810
# 3        K-Nearest Neighbors        0.883333
# 4  support vector classifier        0.957238

# %% [markdown]
# # Test

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_test, y_test)

# %%
LR_y_train_pred = classifier.predict(X_train)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train, LR_y_train_pred))

# %% [markdown]
# ## DT

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_test, y_test)

# %%
DT_y_train_pred = classifier.predict(X_train)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_train, DT_y_train_pred))

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_test, y_test)

# %%
RF_y_train_pred = classifier.predict(X_train)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_train, RF_y_train_pred))

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_test, y_test)

# %%
KNN_y_train_pred = classifier.predict(X_train)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_train, KNN_y_train_pred))

# %% [markdown]
# ## svc

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_test, y_test)

# %%
y_train_pred = svc.predict(X_train)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_train, y_train_pred))

# %%
data_Test = pd.DataFrame([["LogisticRegression",0.878095238095238],["Decision Tree",0.7521904761904762],["Random Forest",0.9241587301587302],["K-Nearest Neighbors",0.8425714285714285],["support vector classifier",0.9353015873015873]])
data_Test.columns=["Test_Classification","Test_Accuracy"]

# %%
data_Test

# %%
df = pd.concat([data,data_Test],axis = 1)

# %%
df.drop(["Test_Classification"],axis = 1)

# %% [markdown]
# # Serialization

# %%
from pickle import dump

dump(knn_classifier, open('models/knn_model.pkl', 'wb'))
dump(lr_classifier, open('models/lr_model.pkl', 'wb'))
dump(rf_classifier, open('models/rf_model.pkl', 'wb'))
dump(dt_classifier, open('models/dt_model.pkl', 'wb'))
dump(sv_classifier, open('models/sv_model.pkl', 'wb'))
